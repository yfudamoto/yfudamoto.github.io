# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re
import urllib.parse

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    # "proceeding": {
    #     "file" : "proceedings.bib",
    #     "venuekey": "booktitle",
    #     "venue-pretext": "In the proceedings of ",
    #     "collection" : {"name":"publications",
    #                     "permalink":"/publication/"}
        
    # },
    "journal":{
        "file": "/Users/yfudamoto/Downloads/export-bibtex.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
def format_authors(author_field):
    author_field = author_field.replace("{", "").replace("}", "")

    # split authors
    authors = [a.strip() for a in author_field.split(" and ") if a.strip()]

    if len(authors) <= 3:
        return ", ".join(authors)
    else:
        return ", ".join(authors[:3]) + ", et al."


for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            author_field = " and ".join(str(a) for a in bibdata.entries[bib_id].persons.get("author", []))
            authors_display = format_authors(author_field)
            if authors_display:
                citation = citation + " " + authors_display + ", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                ads_query = urllib.parse.quote(clean_title.replace("-"," "))
                md += "\nUse [NASA ADS](https://ui.adsabs.harvard.edu/search/q=" + ads_query + "){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED 2026AstHe.119...74F: " {Researches in a Journey}  "
# SUCESSFULLY PARSED 2026MNRAS.tmp...14R: " {REBELS-IFU: Evidence for metal-rich massive galaxies at z \ ... "
# SUCESSFULLY PARSED 2026ApJS..282...19F: " {The ALPINE-CRISTAL-JWST Survey: JWST/IFU Optical Observatio ... "
# SUCESSFULLY PARSED 2025arXiv251216215Z: " {ALMA and JWST Identification of Faint Dusty Star-Forming Ga ... "
# SUCESSFULLY PARSED 2025arXiv251208054A: " {Spatially Resolved Physical Properties of Young Star Cluste ... "
# SUCESSFULLY PARSED 2025arXiv251205180Z: " {Little red dot variability over a century reveals black hol ... "
# SUCESSFULLY PARSED 2025MNRAS.tmp.2154B: " {Probing Infrared eXcess to Investigate Early-Universe Dust  ... "
# SUCESSFULLY PARSED 2025MNRAS.544.4722R: " {RIOJA. Young starburst and ionized gas outflows in a z = 7. ... "
# SUCESSFULLY PARSED 2025ApJ...995L...5Z: " {Quasar Radiative Feedback May Suppress Galaxy Growth on Int ... "
# SUCESSFULLY PARSED 2025AJ....170..324G: " {UNIONS: The Ultraviolet Near-infrared Optical Northern Surv ... "
# SUCESSFULLY PARSED 2025arXiv251121820D: " {Little Red Dots host Black Hole Stars: A unified family of  ... "
# SUCESSFULLY PARSED 2025arXiv251118479Z: " {Kinematic Mapping of Giant Arcs: A New Method to Locate Len ... "
# SUCESSFULLY PARSED 2025arXiv251114483N: " {VENUS: A Strongly Lensed Clumpy Galaxy at $z\sim11-12$ behi ... "
# SUCESSFULLY PARSED 2025ApJ...993L..50U: " {ELPIS: Accelerated Metal and Dust Enrichment in a Protoclus ... "
# SUCESSFULLY PARSED 2025arXiv251012411M: " {Extremely UV-bright starbursts at the end of cosmic reioniz ... "
# SUCESSFULLY PARSED 2025arXiv251011788U: " {ELPIS: Accelerated metal and dust enrichment in a proto-clu ... "
# SUCESSFULLY PARSED 2025arXiv251011770F: " {Early massive galaxy formation in the core of a galaxy prot ... "
# SUCESSFULLY PARSED 2025ApJ...991L..38U: " {RIOJA. JWST and ALMA Unveil the Inhomogeneous and Complex I ... "
# SUCESSFULLY PARSED 2025A&A...702A.206A: " {The ALPINE-CRISTAL-JWST survey: Spatially resolved star for ... "
# SUCESSFULLY PARSED 2025A&A...702A.157E: " {Cosmology with supernova Encore in the strong lensing clust ... "
# SUCESSFULLY PARSED 2025arXiv250916071A: " {REBELS-IFU: on the origin of the elevated [OIII]/[CII] rati ... "
# SUCESSFULLY PARSED 2025arXiv250912319S: " {Cosmology with supernova Encore in the strong lensing clust ... "
# SUCESSFULLY PARSED 2025MNRAS.542.1388V: " {The ALMA REBELS survey: [O III]$_{88{\ensuremath{\mu}}m}$ l ... "
# SUCESSFULLY PARSED 2025MNRAS.542..960D: " {JADES and SAPPHIRES: galaxy metamorphosis amidst a huge, lu ... "
# SUCESSFULLY PARSED 2025ApJ...990...29H: " {Compact Ionized Gas Region Surrounded by Porous Neutral Gas ... "
# SUCESSFULLY PARSED 2025arXiv250821708R: " {JWST Spectroscopic Insights Into the Diversity of Galaxies  ... "
# SUCESSFULLY PARSED 2025NatAs...9.1553F: " {Primordial rotating disk composed of at least 15 dense star ... "
# SUCESSFULLY PARSED 2025A&A...700A.231X: " {No [C II] or dust detection in two Little Red Dots at z$_{s ... "
# SUCESSFULLY PARSED 2025arXiv250719706M: " {MINERVA: A NIRCam Medium Band and MIRI Imaging Survey to Un ... "
# SUCESSFULLY PARSED 2025arXiv250706284W: " {Before its time: a remarkably evolved protocluster core at  ... "
# SUCESSFULLY PARSED 2025arXiv250702053M: " {RIOJA. A Clumpy Galaxy Assembly at Redshift 6.81 Revealed b ... "
# SUCESSFULLY PARSED 2025OJAp....8E.123N: " {The Jackknife method as a new approach to validate strong l ... "
# SUCESSFULLY PARSED 2025ApJ...988...19S: " {Detection of [O III]$_{88 {\ensuremath{\mu}}m}$ in JADES-GS ... "
# SUCESSFULLY PARSED 2025arXiv250624128B: " {Beneath the Surface: >85\% of z>5.9 QSOs in Massive Host Ga ... "
# SUCESSFULLY PARSED 2025arXiv250606418S: " {The Identification of Two JWST/NIRCam-Dark Starburst Galaxi ... "
# SUCESSFULLY PARSED 2025ApJS..278...45F: " {DUALZ{\textemdash}Deep UNCOVER-ALMA Legacy High-Z Survey}  "
# SUCESSFULLY PARSED 2025arXiv250511263N: " {A Cosmic Miracle: A Remarkably Luminous Galaxy at $z_{\rm{s ... "
# SUCESSFULLY PARSED 2025arXiv250503873H: " {SAPPHIRES: Extremely Metal-Poor Galaxy Candidates with $12+ ... "
# SUCESSFULLY PARSED 2025MNRAS.539..109F: " {REBELS-IFU: dust attenuation curves of 12 massive galaxies  ... "
# SUCESSFULLY PARSED 2025arXiv250403831F: " {ALMA Observations of [OI]145um and [NII]205um Emission line ... "
# SUCESSFULLY PARSED 2025arXiv250402305Z: " {Nuclear Winds Drive Cold Gas Outflows on Kiloparsec Scales  ... "
# SUCESSFULLY PARSED 2025arXiv250317478N: " {A stellar dynamical mass measure of an inactive black hole  ... "
# SUCESSFULLY PARSED 2025arXiv250316596N: " {A ``Black Hole Star'' Reveals the Remarkable Gas-Enshrouded ... "
# SUCESSFULLY PARSED 2025arXiv250315597F: " {SAPPHIRES: A Galaxy Over-Density in the Heart of Cosmic Rei ... "
# SUCESSFULLY PARSED 2025arXiv250315587S: " {Slitless Areal Pure-Parallel HIgh-Redshift Emission Survey  ... "
# SUCESSFULLY PARSED 2025NatAs...9..428F: " {Identification of more than 40 gravitationally magnified st ... "
# SUCESSFULLY PARSED 2025MNRAS.537.3453B: " {Quiescent or dusty? Unveiling the nature of extremely red g ... "
# SUCESSFULLY PARSED 2025ApJ...982...51P: " {The UNCOVER Survey: First Release of Ultradeep JWST/NIRSpec ... "
# SUCESSFULLY PARSED 2025ApJ...981..135S: " {RIOJA. Complex Dusty Starbursts in a Major Merger B14-65666 ... "
# SUCESSFULLY PARSED 2025arXiv250201610S: " {Deep Constraints on [CII]158$\mu$m in JADES-GS-z14-0: Furth ... "
# SUCESSFULLY PARSED 2025PASJ...77..139I: " {Detection of the [O I] 63 {\textmu}m emission line from the ... "
# SUCESSFULLY PARSED 2025A&A...694A.178C: " {An H{\ensuremath{\alpha}} view of galaxy buildup in the fir ... "
# SUCESSFULLY PARSED 2025ApJ...978L...5B: " {Dark Matter Distinguished by Skewed Microlensing in the ``D ... "
# SUCESSFULLY PARSED 2024arXiv241204557L: " {An unambiguous AGN and a Balmer break in an Ultraluminous L ... "
# SUCESSFULLY PARSED 2024PASJ...76.1323T: " {Crimson Behemoth: A massive clumpy structure hosting a dust ... "
# SUCESSFULLY PARSED 2024ApJ...977..250F: " {UNCOVER: A NIRSpec Census of Lensed Galaxies at z = 8.50{\t ... "
# SUCESSFULLY PARSED 2024RNAAS...8..284Z: " {Discovery of a Unique Close Quasar{\textendash}DSFG Pair Li ... "
# SUCESSFULLY PARSED 2024Natur.635..311X: " {Accelerated formation of ultra-massive galaxies in the firs ... "
# SUCESSFULLY PARSED 2024MNRAS.535.1067M: " {JWST FRESCO: a comprehensive census of H {\ensuremath{\beta ... "
# SUCESSFULLY PARSED 2024MNRAS.534.3552S: " {JWST/NIRSpec spectroscopy of intermediate-mass quiescent ga ... "
# SUCESSFULLY PARSED 2024ApJ...976..101S: " {Medium Bands, Mega Science: A JWST/NIRCam Medium-band Imagi ... "
# SUCESSFULLY PARSED 2024AstHe.117..600F: " {JWST Observations of Gravitationally Lensed Galaxies}  "
# SUCESSFULLY PARSED 2024A&A...690A..64M: " {A first look at spatially resolved star formation at 4.8 <  ... "
# SUCESSFULLY PARSED 2024MNRAS.533.3098A: " {Accurate simultaneous constraints on the dust mass, tempera ... "
# SUCESSFULLY PARSED 2024A&A...689A.167D: " {Imaging dark matter at the smallest scales with z {\ensurem ... "
# SUCESSFULLY PARSED 2024MNRAS.532.2270B: " {Gas conditions of a star-formation selected sample in the f ... "
# SUCESSFULLY PARSED 2024A&A...688A..55M: " {A$^{3}$COSMOS: Measuring the cosmic dust-attenuated star fo ... "
# SUCESSFULLY PARSED 2024MNRAS.531.3222K: " {The ALPINE-ALMA [C II] survey: characterization of spatial  ... "
# SUCESSFULLY PARSED 2024arXiv240607975T: " {FINER: Far-Infrared Nebular Emission Receiver for the Large ... "
# SUCESSFULLY PARSED 2024MNRAS.530..966G: " {Unveiling the hidden Universe with JWST: the contribution o ... "
# SUCESSFULLY PARSED 2024MNRAS.530..340F: " {The NOEMA observations of GN-z11: constraining the neutral  ... "
# SUCESSFULLY PARSED 2024Natur.628...57F: " {A high black-hole-to-host mass ratio in a lensed AGN in the ... "
# SUCESSFULLY PARSED 2024MNRAS.529.4531Z: " {Revisiting the Dragonfly galaxy II. Young, radiatively effi ... "
# SUCESSFULLY PARSED 2024ApJ...964..146F: " {JWST and ALMA Multiple-line Study in and around a Galaxy at ... "
# SUCESSFULLY PARSED 2024MNRAS.528.6934S: " {Protoclusters as drivers of stellar mass growth in the earl ... "
# SUCESSFULLY PARSED 2024Natur.626..975A: " {Most of the photons that reionized the Universe came from d ... "
# SUCESSFULLY PARSED 2024A&A...682A..24A: " {The ALMA Reionization Era Bright Emission Line Survey: The  ... "
# SUCESSFULLY PARSED 2024MNRAS.527.6867A: " {Cold dust and low [O III]/[C II] ratios: an evolved star-fo ... "
# SUCESSFULLY PARSED 2024MNRAS.527.5808B: " {The ALMA REBELS survey: obscured star formation in massive  ... "
# SUCESSFULLY PARSED 2024ApJS..270....7W: " {The UNCOVER Survey: A First-look HST + JWST Catalog of 60,0 ... "
# SUCESSFULLY PARSED 2024ApJ...961...71F: " {The Extended [C II] under Construction? Observation of the  ... "
# SUCESSFULLY PARSED 2023A&A...680L...8B: " {The ALMA-ALPINE [CII] survey: Kennicutt-Schmidt relation in ... "
# SUCESSFULLY PARSED 2023ApJ...957L..34W: " {UNCOVER: Illuminating the Early Universe-JWST/NIRSpec Confi ... "
# SUCESSFULLY PARSED 2023ApJ...957L...7K: " {UNCOVER: A NIRSpec Identification of a Broad-line AGN at z  ... "
# SUCESSFULLY PARSED 2023arXiv231009327L: " {MAGNIF: A Tentative Lensed Rotating Disk at $z=8.34$ detect ... "
# SUCESSFULLY PARSED 2023MNRAS.525.2864O: " {The JWST FRESCO survey: legacy NIRCam/grism spectroscopy an ... "
# SUCESSFULLY PARSED 2023ApJ...955..130F: " {ALMA FIR View of Ultra-high-redshift Galaxy Candidates at z ... "
# SUCESSFULLY PARSED 2023MNRAS.524.1775H: " {The ALMA REBELS Survey: discovery of a massive, highly star ... "
# SUCESSFULLY PARSED 2023ApJ...955L..24G: " {UNCOVER: The Growth of the First Massive Black Holes from J ... "
# SUCESSFULLY PARSED 2023ApJ...955L...2H: " {Reionization and the ISM/Stellar Origins with JWST and ALMA ... "
# SUCESSFULLY PARSED 2023ApJ...952..142F: " {JWST UNCOVER: Extremely Red and Compact Object at z $_{phot ... "
# SUCESSFULLY PARSED 2023MNRAS.522.6123Z: " {Revisiting the Dragonfly galaxy - I. High-resolution ALMA a ... "
# SUCESSFULLY PARSED 2023MNRAS.522.3926B: " {The ALMA REBELS Survey: the first infrared luminosity funct ... "
# SUCESSFULLY PARSED 2023ApJ...952...48H: " {Big Three Dragons: Molecular Gas in a Bright Lyman-break Ga ... "
# SUCESSFULLY PARSED 2023A&A...675A..30B: " {The ALPINE-ALMA [CII] survey: Double stellar population and ... "
# SUCESSFULLY PARSED 2023MNRAS.522..449B: " {Unveiling the nature of infrared bright, optically dark gal ... "
# SUCESSFULLY PARSED 2023MNRAS.522..275J: " {An investigation of the circumgalactic medium around z {\en ... "
# SUCESSFULLY PARSED 2023MNRAS.521.2962F: " {Estimating dust temperature and Far-IR luminosity of high-r ... "
# SUCESSFULLY PARSED 2023ApJ...948....3U: " {Detections of [C II] 158 {\ensuremath{\mu}}m and [O III] 88 ... "
# SUCESSFULLY PARSED 2023ApJ...945...69R: " {Updated Measurements of [O III] 88 {\ensuremath{\mu}}m, [C  ... "
# SUCESSFULLY PARSED 2023A&A...671A.123B: " {Identification of large equivalent width dusty galaxies at  ... "
# SUCESSFULLY PARSED 2023MNRAS.518.6142A: " {The ALMA REBELS survey: the dust-obscured cosmic star forma ... "
# SUCESSFULLY PARSED 2023MNRAS.518.3702I: " {Correction to: The ALMA REBELS Survey: dust continuum detec ... "
# SUCESSFULLY PARSED 2023MNRAS.518..691J: " {Evidence for extended gaseous reservoirs around AGN at cosm ... "
# SUCESSFULLY PARSED 2022MNRAS.516..975T: " {The ALMA REBELS Survey: specific star formation rates in th ... "
# SUCESSFULLY PARSED 2022ApJ...938L..24F: " {Red Spiral Galaxies at Cosmic Noon Unveiled in the First JW ... "
# SUCESSFULLY PARSED 2022MNRAS.515.3126I: " {The ALMA REBELS Survey: dust continuum detections at z > 6. ... "
# SUCESSFULLY PARSED 2022ApJ...935..119S: " {Bridging Optical and Far-infrared Emission-line Diagrams of ... "
# SUCESSFULLY PARSED 2022ApJ...934L..27H: " {The ALMA REBELS Survey: The Cosmic H I Gas Mass Density in  ... "
# SUCESSFULLY PARSED 2022ApJ...934..144F: " {The ALMA REBELS Survey: Average [C II] 158 {\ensuremath{\mu ... "
# SUCESSFULLY PARSED 2022A&A...664A..73B: " {The ALMA-ALPINE [CII] survey. The star formation history an ... "
# SUCESSFULLY PARSED 2022MNRAS.513.3122S: " {The ALMA REBELS Survey: cosmic dust temperature evolution o ... "
# SUCESSFULLY PARSED 2022AstHe.115..461F: " {The Rise of Normal, Dust-Obscured Galaxies during Cosmic Re ... "
# SUCESSFULLY PARSED 2022ApJ...933L..19T: " {Possible Systematic Rotation in the Mature Stellar Populati ... "
# SUCESSFULLY PARSED 2022Univ....8..314F: " {ALPINE: A Large Survey to Understand Teenage Galaxies}  "
# SUCESSFULLY PARSED 2022ApJ...931..160B: " {Reionization Era Bright Emission Line Survey: Selection and ... "
# SUCESSFULLY PARSED 2022MNRAS.512..989D: " {The ALMA REBELS survey: the dust content of z 7 Lyman break ... "
# SUCESSFULLY PARSED 2022MNRAS.512...58F: " {The ALMA REBELS Survey. Epoch of Reionization giants: Prope ... "
# SUCESSFULLY PARSED 2022ApJ...929....1H: " {A Search for H-Dropout Lyman Break Galaxies at z 12-16}  "
# SUCESSFULLY PARSED 2022MNRAS.511.1303V: " {The ALPINE-ALMA [C II] survey: Investigation of 10 galaxies ... "
# SUCESSFULLY PARSED 2022ApJ...928...68S: " {Infrared Spectral Energy Distributions and Dust Masses of S ... "
# SUCESSFULLY PARSED 2022ApJ...928...31S: " {Significant Dust-obscured Star Formation in Luminous Lyman- ... "
# SUCESSFULLY PARSED 2021MNRAS.507.3540J: " {The ALPINE-ALMA [C II] Survey: kinematic diversity and rota ... "
# SUCESSFULLY PARSED 2021Natur.597..489F: " {Normal, dust-obscured galaxies in the epoch of reionization ... "
# SUCESSFULLY PARSED 2021A&A...653A..84P: " {The ALPINE-ALMA [CII] survey. Dust mass budget in the early ... "
# SUCESSFULLY PARSED 2021ApJ...912...67U: " {The ALMA Spectroscopic Survey in the HUDF: A Search for [C  ... "
# SUCESSFULLY PARSED 2021A&A...649A.152K: " {The ALPINE-ALMA [CII] survey. Obscured star formation rate  ... "
# SUCESSFULLY PARSED 2021A&A...646A..76L: " {The ALPINE-ALMA [C II] survey. Luminosity function of seren ... "
# SUCESSFULLY PARSED 2020MNRAS.498.4192F: " {ALMA characterizes the dust temperature of z {\ensuremath{\ ... "
# SUCESSFULLY PARSED 2020A&A...643A...7G: " {The ALPINE-ALMA [CII] survey. Circumgalactic medium polluti ... "
# SUCESSFULLY PARSED 2020A&A...643A...6C: " {The ALPINE-ALMA [CII] survey. Small Ly{\ensuremath{\alpha}} ... "
# SUCESSFULLY PARSED 2020A&A...643A...5D: " {The ALPINE-ALMA [C II] survey. Molecular gas budget in the  ... "
# SUCESSFULLY PARSED 2020A&A...643A...4F: " {The ALPINE-ALMA [CII] survey. Dust attenuation properties a ... "
# SUCESSFULLY PARSED 2020A&A...643A...3S: " {The ALPINE-ALMA [C II] survey. Little to no evolution in th ... "
# SUCESSFULLY PARSED 2020A&A...643A...2B: " {The ALPINE-ALMA [CII] survey: Data processing, catalogs, an ... "
# SUCESSFULLY PARSED 2020A&A...643A...1L: " {The ALPINE-ALMA [CII] survey. Survey strategy, observations ... "
# SUCESSFULLY PARSED 2020ApJ...902..112B: " {The ALMA Spectroscopic Survey Large Program: The Infrared E ... "
# SUCESSFULLY PARSED 2020ApJ...900....1F: " {The ALPINE-ALMA [C II] Survey: Size of Individual Star-form ... "
# SUCESSFULLY PARSED 2020MNRAS.496..875R: " {The ALPINE-ALMA [C II] Survey: on the nature of an extremel ... "
# SUCESSFULLY PARSED 2020ApJS..247...61F: " {The ALPINE-ALMA [C II] Survey: Multiwavelength Ancillary Da ... "
# SUCESSFULLY PARSED 2020MNRAS.491.4724F: " {A3COSMOS: the dust attenuation of star-forming galaxies at  ... "
# SUCESSFULLY PARSED 2020MNRAS.491L..18J: " {The ALPINE-ALMA [C II] survey: a triple merger at z {\ensur ... "
# SUCESSFULLY PARSED 2020A&A...633A..90G: " {The ALPINE-ALMA [C II] survey: Star-formation-driven outflo ... "
# SUCESSFULLY PARSED 2019ApJ...887..235L: " {Automated Mining of the ALMA Archive in the COSMOS Field (A ... "
# SUCESSFULLY PARSED 2019ApJS..244...40L: " {Automated Mining of the ALMA Archive in the COSMOS Field (A ... "
# SUCESSFULLY PARSED 2019ApJ...879...54L: " {Revealing the Stellar Mass and Dust Distributions of Submil ... "
# SUCESSFULLY PARSED 2018A&A...615A...7L: " {Probing star formation and ISM properties using galaxy disk ... "
# SUCESSFULLY PARSED 2017MNRAS.472.2028F: " {The most distant, luminous, dusty star-forming galaxies: re ... "
# SUCESSFULLY PARSED 2017MNRAS.472..483F: " {The dust attenuation of star-forming galaxies at z {\ensure ... "
# SUCESSFULLY PARSED 2017ApJ...844...85O: " {A New Constraint on Reionization from the Evolution of the  ... "
# SUCESSFULLY PARSED 2016ApJ...833...71A: " {The ALMA Spectroscopic Survey in the Hubble Ultra Deep Fiel ... "
# SUCESSFULLY PARSED 2015ApJ...799..209W: " {The KMOS$^{3D}$ Survey: Design, First Results, and the Evol ... "
